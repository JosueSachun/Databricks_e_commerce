-- %% [markdown]
-- ##Crear External Locations gold con SQL

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS gold_databricks_external_location
  URL 'abfss://gold@saexternaldatabricks.dfs.core.windows.net/'
  WITH (STORAGE CREDENTIAL `databricks-external-storage-credential`);

-- %%
DESC EXTERNAL LOCATION gold_databricks_external_location;

-- %%
%fs
ls "abfss://bronze@saexternaldatabricks.dfs.core.windows.net/"
