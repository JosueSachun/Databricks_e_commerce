-- %%
USE e_commerce.silver

-- %%
%run "../src/utils/merge"

-- %%
SELECT customer_id, COUNT(order_id) qnt_sales FROM t_order_x_product GROUP BY customer_id ORDER BY qnt_sales DESC;

-- %%
CREATE OR REPLACE TABLE gold.t_sales_by_customer
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/t_sales_by_customer'
AS
SELECT
  customer_id,
  COUNT(order_id) qnt_sales
FROM
  t_order_x_product
GROUP BY
  customer_id
ORDER BY
  qnt_sales DESC;

-- %%
SELECT * FROM gold.t_sales_by_customer;
