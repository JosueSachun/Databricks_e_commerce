-- %%
USE e_commerce.bronze;

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.customer(
  customer_id VARCHAR(50),
  customer_unique_id VARCHAR(50),
  zip_code_prefix VARCHAR(40),
  city VARCHAR(40),
  state VARCHAR(40),
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/customer'

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.geolocation(
  zip_code_prefix VARCHAR(50),
  latitude DOUBLE,
  longitude DOUBLE,
  city VARCHAR(70),
  state VARCHAR(70),
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/geolocation'

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.order_item(
  order_id VARCHAR(50),
  order_item_id VARCHAR(50),
  product_id VARCHAR(50),
  seller_id VARCHAR(50),
  shipping_limit_date TIMESTAMP,
  price DOUBLE,
  freight_value DOUBLE,
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/order_item'

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.order(
  order_id VARCHAR(50),
  customer_id VARCHAR(50),
  status VARCHAR(50),
  purchase_date TIMESTAMP,
  approved_date TIMESTAMP,
  carrier_date TIMESTAMP,
  customer_date TIMESTAMP,
  estimated_delivery_date TIMESTAMP,
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/order'

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.order_review(
  review_id VARCHAR(50),
  order_id VARCHAR(50),
  score INT,
  comment_title VARCHAR(50),
  comment_message VARCHAR(100),
  creation_date TIMESTAMP,
  answer_timestamp TIMESTAMP,
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/order_review'

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.payment(
  order_id VARCHAR(50),
  sequential INT,
  type VARCHAR(50),
  installments INT,
  value DOUBLE,
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/payment'

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.product_category_name_translation(
  product_category_name VARCHAR(100),
  product_category_name_english VARCHAR(100),
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/product_category_name_translation'

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.product(
  product_id VARCHAR(50),
  category_name VARCHAR(100),
  name_lenght INT,
  description_lenght INT,
  photos_qty INT,
  weight_g INT,
  length_cm INT,
  height_cm INT,
  width_cm INT,
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/product'

-- %%
CREATE TABLE IF NOT EXISTS e_commerce.silver.seller(
  seller_id VARCHAR(50),
  zip_code_prefix VARCHAR(50),
  city VARCHAR(70),
  state VARCHAR(70),
  ingestion_timestamp TIMESTAMP,
  environment VARCHAR(50),
  file_date DATE,
  source_name STRING
)
USING DELTA
LOCATION 'abfss://silver@saexternaldatabricks.dfs.core.windows.net/seller'
