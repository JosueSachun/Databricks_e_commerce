# %%
land_folder_path = "abfss://landing@saexternaldatabricks.dfs.core.windows.net"
bronze_folder_path = "abfss://bronze@saexternaldatabricks.dfs.core.windows.net"
silver_folder_path = "abfss://silver@saexternaldatabricks.dfs.core.windows.net"
gold_folder_path = "abfss://gold@saexternaldatabricks.dfs.core.windows.net"
